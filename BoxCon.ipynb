# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='whitegrid')

# %%
df=pd.read_csv('D:\\python\\Titanic_ML\\box_office\\box_office_predictions.csv')

# %%
df.sample(5)
# Out:
#           budget country           director   genre       gross  \
# 1017  60000000.0   China       Edward Zwick  Action  58399160.0
# 1018  22000000.0     USA      Kevin Costner   Drama  58331254.0
# 557   80000000.0     USA      Albert Hughes  Action  94835059.0
# 5226         0.0     USA    Robert M. Young   Drama    315752.0
# 2209  10000000.0     USA  Jocelyn Moorhouse  Comedy  23574130.0
#
#                                       name rating  runtime  score  \
# 1017      Jack Reacher: Sin regreso (2016)  PG-13      118    6.1
# 1018                     Open Range (2003)      R      139    7.5
# 557                 The Book of Eli (2010)      R      118    6.9
# 5226                         Caught (1996)      R      110    6.8
# 2209  How to Make an American Quilt (1995)  PG-13      117    6.2
#
#                     star               studio   votes
# 1017          Tom Cruise   Paramount Pictures   91452
# 1018       Kevin Costner  Touchstone Pictures   57656
# ...

# %%
df.loc[df['score']<6.7 , 'score']=0
df.loc[df['score']>6.7, 'score']=1
df.head()
# Out:
#         budget country           director   genre        gross  \
# 0  237000000.0      UK      James Cameron  Action  760507625.0
# 1  200000000.0     USA      James Cameron   Drama  658672302.0
# 2  150000000.0     USA    Colin Trevorrow  Action  652270625.0
# 3  220000000.0     USA        Joss Whedon  Action  623357910.0
# 4  185000000.0     USA  Christopher Nolan  Action  534858444.0
#
#                      name rating  runtime  score               star  \
# 0           Avatar (2009)  PG-13      162    1.0    Sam Worthington
# 1          Titanic (1997)  PG-13      194    1.0  Leonardo DiCaprio
# 2   Jurassic World (2015)  PG-13      124    1.0        Chris Pratt
# 3     The Avengers (2012)  PG-13      143    1.0  Robert Downey Jr.
# 4  The Dark Knight (2008)  PG-13      152    1.0     Christian Bale
#
#                                    studio    votes
# 0  Twentieth Century Fox Film Corporation   958400
# 1  Twentieth Century Fox Film Corporation   865551
# ...

# %%
df[['score', 'rating']].groupby(['rating'], as_index=False).mean().sort_values(by='rating', ascending=False)
# Out:
#            rating     score
# 12        UNRATED  0.667241
# 11          TV-PG  0.000000
# 10          TV-MA  1.000000
# 9           TV-14  1.000000
# 8               R  0.708973
# 7           PG-13  0.638620
# 6              PG  0.576319
# 5   Not specified  0.989286
# 4       NOT RATED  0.990728
# 3           NC-17  0.500000
# 2               G  0.602256
# 1             B15  0.000000
# 0               B  1.000000

# %%
df[['director', 'score']].groupby(['director'], as_index=False).mean().sort_values(by='director', ascending=False)
# Out:
#                         director     score
# 2548                  Éva Gárdos  1.000000
# 2547           Étienne Chatiliez  1.000000
# 2546                 Éric Rohmer  1.000000
# 2545              Élie Chouraqui  0.000000
# 2544                Åke Sandgren  0.000000
# 2543          Álex de la Iglesia  0.333333
# 2542                 Zoya Akhtar  1.000000
# 2541               Zoran Perisic  0.000000
# 2540         Zoe Clarke-Williams  0.000000
# 2539                Ziad Doueiri  1.000000
# 2538           Zhuangzhuang Tian  1.000000
# 2537                Zelda Barron  0.000000
# 2536                 Zalman King  0.000000
# 2535              Zal Batmanglij  3.850000
# 2534                 Zack Snyder  0.714286
# 2533             Zacharias Kunuk  1.000000
# 2532                   Zach Helm  0.000000
# 2531                Zach Cregger  0.000000
# 2530                  Zach Braff  3.850000
# 2529                 Yves Robert  1.000000
# 2528            Yorgos Lanthimos  0.666667
# ...

# %%
df.head(4)
# Out:
#         budget country         director   genre        gross  \
# 0  237000000.0      UK    James Cameron  Action  760507625.0
# 1  200000000.0     USA    James Cameron   Drama  658672302.0
# 2  150000000.0     USA  Colin Trevorrow  Action  652270625.0
# 3  220000000.0     USA      Joss Whedon  Action  623357910.0
#
#                     name rating  runtime  score               star  \
# 0          Avatar (2009)  PG-13      162    1.0    Sam Worthington
# 1         Titanic (1997)  PG-13      194    1.0  Leonardo DiCaprio
# 2  Jurassic World (2015)  PG-13      124    1.0        Chris Pratt
# 3    The Avengers (2012)  PG-13      143    1.0  Robert Downey Jr.
#
#                                    studio    votes
# 0  Twentieth Century Fox Film Corporation   958400
# 1  Twentieth Century Fox Film Corporation   865551
# 2                      Universal Pictures   470625
# 3                          Marvel Studios  1069292

# %%
y=sns.FacetGrid(df, col='score')
y.map(plt.hist, 'runtime', bins=10)

# %%
df['country'].value_counts()
# Out:
# USA                               4281
# UK                                 615
# France                             249
# Canada                             126
# Germany                            119
# Australia                           71
# Japan                               59
# Spain                               50
# Italy                               47
# Ireland                             40
# Hong Kong                           38
# India                               36
# Denmark                             31
# China                               23
# South Korea                         18
# New Zealand                         17
# Sweden                              17
# Belgium                             15
# Mexico                              13
# Netherlands                         12
# Iran                                10
# Argentina                           10
# Russia                              10
# Norway                               8
# ...

# %%
df['genre'].value_counts()
# Out:
# Comedy       1818
# Drama        1280
# Action       1175
# Crime         463
# Adventure     340
# Biography     309
# Animation     246
# Horror        243
# Mystery        34
# Fantasy        28
# Thriller       17
# Romance        14
# Sci-Fi         13
# Family         12
# Musical         4
# War             2
# Western         2
# Name: genre, dtype: int64

# %%
train_test_data=[df]

# %%
genre_mapping={"Comedy":0,"Drama":0.5,"Action":1,"Crime":1.5,"Adventure":2,"Biography":2.5,"Animation":3,
              "Horror":3.5,"Mystery":4,"Fantasy":5,"Thriller":5.5,"Romance":6,"Sci-Fi":6.5,"Family":7,"Musical":7.5,
              "Western":8,"War":8.5}
for dataset in train_test_data:
    dataset['genre']=dataset['genre'].map(genre_mapping)

# %%
df.sample(5)
# Out:
#           budget country           director  genre        gross  \
# 2392  19000000.0     USA        Ben Affleck    1.5   20300218.0
# 2238         0.0     USA       Dito Montiel    1.0   23036320.0
# 271   80000000.0     USA       Dean DeBlois    3.0  145794338.0
# 4022         0.0     USA  Michael O. Sajbel    0.5    3438735.0
# 2099  31000000.0     USA      David S. Ward    0.0   25785603.0
#
#                           name rating  runtime  score            star  \
# 2392     Gone Baby Gone (2007)      R      114    1.0  Morgan Freeman
# 2238           Fighting (2009)  PG-13      105    0.0  Channing Tatum
# 271       Lilo & Stitch (2002)     PG       85    1.0   Daveigh Chase
# 4022  The Ultimate Gift (2006)     PG      100    1.0     Drew Fuller
# 2099     Down Periscope (1996)  PG-13       92    0.0  Kelsey Grammer
#
#                                       studio   votes
# 2392                              LivePlanet  213770
# ...

# %%
df.describe()
# Out:
#              budget        genre         gross      runtime        score  \
# count  6.000000e+03  6000.000000  6.000000e+03  6000.000000  6000.000000
# mean   2.469918e+07     1.039250  3.341635e+07   106.587000     0.676550
# std    3.721710e+07     1.185813  5.735205e+07    18.026885     1.389726
# min    0.000000e+00     0.000000  4.410000e+02    50.000000     0.000000
# 25%    0.000000e+00     0.000000  1.527796e+06    95.000000     0.000000
# 50%    1.100000e+07     0.500000  1.229897e+07   102.000000     0.000000
# 75%    3.262500e+07     1.500000  4.007256e+07   115.000000     1.000000
# max    3.000000e+08     8.500000  7.605076e+08   366.000000     6.700000
#
#               votes
# count  6.000000e+03
# mean   7.188537e+04
# std    1.308033e+05
# min    2.700000e+01
# 25%    7.791750e+03
# 50%    2.660150e+04
# 75%    7.677475e+04
# max    1.868308e+06

# %%
y=sns.barplot(df.genre, df.score, data=df, color='salmon',saturation=1)

# %%
sns.barplot(df.genre, df.gross, data=df, color='c' )

# %%
sns.boxplot(df.genre, df.runtime, color='m', saturation=0.75, notch=True, dodge=True)

# %%
df[['country', 'score']].groupby(['country'], as_index=False).mean().sort_values(by='country', ascending=False)
# Out:
#                            country     score
# 51                    West Germany  0.750000
# 50                             USA  0.602149
# 49                              UK  0.885854
# 48                        Thailand  1.000000
# 47                          Taiwan  0.857143
# 46                     Switzerland  1.000000
# 45                          Sweden  1.217647
# 44                           Spain  0.988000
# 43                    Soviet Union  1.000000
# 42                     South Korea  1.261111
# 41                    South Africa  0.666667
# 40                    Saudi Arabia  1.000000
# 39                          Russia  1.270000
# 38                         Romania  0.666667
# 37           Republic of Macedonia  1.000000
# 36                        Portugal  0.500000
# 35                          Poland  0.500000
# 34                            Peru  0.000000
# 33                       Palestine  1.000000
# 32                          Norway  1.462500
# ...

# %%
sns.barplot(df.genre, df.votes, color='c')

# %%
sns.barplot(df.score, df.votes)

# %%
df['votes'].mean()
# Out:
# 71885.36716666666

# %%
df.loc[df['votes']<71885, 'votes']=0
df.loc[df['votes']>71885, 'votes']=1

df.head()
# Out:
#         budget country           director  genre        gross  \
# 0  237000000.0      UK      James Cameron    1.0  760507625.0
# 1  200000000.0     USA      James Cameron    0.5  658672302.0
# 2  150000000.0     USA    Colin Trevorrow    1.0  652270625.0
# 3  220000000.0     USA        Joss Whedon    1.0  623357910.0
# 4  185000000.0     USA  Christopher Nolan    1.0  534858444.0
#
#                      name rating  runtime  score               star  \
# 0           Avatar (2009)  PG-13      162    1.0    Sam Worthington
# 1          Titanic (1997)  PG-13      194    1.0  Leonardo DiCaprio
# 2   Jurassic World (2015)  PG-13      124    1.0        Chris Pratt
# 3     The Avengers (2012)  PG-13      143    1.0  Robert Downey Jr.
# 4  The Dark Knight (2008)  PG-13      152    1.0     Christian Bale
#
#                                    studio  votes
# 0  Twentieth Century Fox Film Corporation      1
# 1  Twentieth Century Fox Film Corporation      1
# ...

# %%
sns.barplot(df.genre, df.votes)

# %%
sns.barplot(df.score, df.votes)

# %%
sns.barplot(df.votes, df.gross, data=df)

# %%
sns.barplot(df.votes, df.runtime)

# %%
df.sample(3)
# Out:
#           budget country     director  genre       gross  \
# 5582         0.0     USA   Rob Reiner    0.0    100910.0
# 3097  30000000.0     USA  Woody Allen    0.0  11103205.0
# 1063  80000000.0     USA  Simon Wells    1.0  56684819.0
#
#                                 name rating  runtime  score             star  \
# 5582  The Magic of Belle Isle (2012)     PG      109    1.0   Morgan Freeman
# 3097             Café Society (2016)  PG-13       96    6.7  Jesse Eisenberg
# 1063         The Time Machine (2002)  PG-13       96    0.0       Guy Pearce
#
#                         studio  votes
# 5582         Magnolia Pictures      0
# 3097  FilmNation Entertainment      0
# 1063              Warner Bros.      1

# %%
df['country'].value_counts()
# Out:
# USA                               4281
# UK                                 615
# France                             249
# Canada                             126
# Germany                            119
# Australia                           71
# Japan                               59
# Spain                               50
# Italy                               47
# Ireland                             40
# Hong Kong                           38
# India                               36
# Denmark                             31
# China                               23
# South Korea                         18
# New Zealand                         17
# Sweden                              17
# Belgium                             15
# Mexico                              13
# Netherlands                         12
# Iran                                10
# Argentina                           10
# Russia                              10
# Norway                               8
# ...

# %%
df['rating'].value_counts()
# Out:
# R                3009
# PG-13            1753
# PG                815
# NOT RATED         151
# G                 133
# UNRATED            58
# Not specified      56
# NC-17              20
# TV-PG               1
# TV-14               1
# TV-MA               1
# B                   1
# B15                 1
# Name: rating, dtype: int64

# %%
rating_mapping={"R":0.0,"PG-13":0.5,"PG":1.0, "NOT RATED":1.5,"G":2.0,"UNRATED":2.5,"Not specified":3.0,
                "NC-17":3.5,"TV-PG":4.0,"TV-14":4.5,"TV-MA":5.0,"B":5.5,"B15":6}

for dataset in train_test_data:
    dataset['rating']=dataset['rating'].map(rating_mapping)

# %%
df.head()
# Out:
#         budget country           director  genre        gross  \
# 0  237000000.0      UK      James Cameron    1.0  760507625.0
# 1  200000000.0     USA      James Cameron    0.5  658672302.0
# 2  150000000.0     USA    Colin Trevorrow    1.0  652270625.0
# 3  220000000.0     USA        Joss Whedon    1.0  623357910.0
# 4  185000000.0     USA  Christopher Nolan    1.0  534858444.0
#
#                      name  rating  runtime  score               star  \
# 0           Avatar (2009)     0.5      162    1.0    Sam Worthington
# 1          Titanic (1997)     0.5      194    1.0  Leonardo DiCaprio
# 2   Jurassic World (2015)     0.5      124    1.0        Chris Pratt
# 3     The Avengers (2012)     0.5      143    1.0  Robert Downey Jr.
# 4  The Dark Knight (2008)     0.5      152    1.0     Christian Bale
#
#                                    studio  votes
# 0  Twentieth Century Fox Film Corporation      1
# 1  Twentieth Century Fox Film Corporation      1
# ...

# %%
sns.barplot(df.rating, df.score, data=df)

# %%
sns.barplot(df.rating, df.votes, data=df)

# %%
sns.barplot(df.rating, df.genre, data=df)

# %%
sns.barplot(df.rating, df.gross, data=df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 12 columns):
# budget      6000 non-null float64
# country     6000 non-null object
# director    6000 non-null object
# genre       6000 non-null float64
# gross       6000 non-null float64
# name        6000 non-null object
# rating      6000 non-null float64
# runtime     6000 non-null int64
# score       6000 non-null float64
# star        6000 non-null object
# studio      6000 non-null object
# votes       6000 non-null int64
# dtypes: float64(5), int64(2), object(5)
# memory usage: 562.6+ KB

# %%
df['star'].value_counts()
# Out:
# Nicolas Cage          38
# Robert De Niro        35
# Denzel Washington     29
# Tom Hanks             29
# Bruce Willis          28
# Johnny Depp           27
# Tom Cruise            26
# Adam Sandler          26
# John Travolta         25
# Kevin Costner         24
# Keanu Reeves          24
# Sylvester Stallone    23
# Robin Williams        22
# Eddie Murphy          21
# Jim Carrey            21
# George Clooney        21
# Matt Damon            21
# Mark Wahlberg         21
# John Cusack           21
# Brad Pitt             21
# Steve Martin          20
# Ben Stiller           20
# Dennis Quaid          20
# Ethan Hawke           20
# Jackie Chan           20
# Sandra Bullock        19
# Mel Gibson            19
# Richard Gere          19
# Jeff Bridges          18
# Will Ferrell          18
#                       ..
# Matt Frewer            1
# Teri Garr              1
# Katrin Cartlidge       1
# Kristy McNichol        1
# Bárbara Mori           1
# Reiko Aylesworth       1
# ...

# %%
df['studio'].value_counts()
# Out:
# Universal Pictures                        269
# Warner Bros.                              265
# Paramount Pictures                        229
# Twentieth Century Fox Film Corporation    176
# New Line Cinema                           146
# Columbia Pictures Corporation             143
# Touchstone Pictures                       112
# Columbia Pictures                          96
# Walt Disney Pictures                       94
# Metro-Goldwyn-Mayer (MGM)                  82
# TriStar Pictures                           78
# Miramax                                    64
# DreamWorks                                 62
# Castle Rock Entertainment                  57
# Fox Searchlight Pictures                   52
# Dimension Films                            51
# Fox 2000 Pictures                          49
# Hollywood Pictures                         43
# Screen Gems                                40
# Summit Entertainment                       37
# ...

# %%
for dataset in train_test_data:
    dataset['country']=dataset['country'].str[:1]

# %%
df.head()
# Out:
#         budget country           director  genre        gross  \
# 0  237000000.0       U      James Cameron    1.0  760507625.0
# 1  200000000.0       U      James Cameron    0.5  658672302.0
# 2  150000000.0       U    Colin Trevorrow    1.0  652270625.0
# 3  220000000.0       U        Joss Whedon    1.0  623357910.0
# 4  185000000.0       U  Christopher Nolan    1.0  534858444.0
#
#                      name  rating  runtime  score               star  \
# 0           Avatar (2009)     0.5      162    1.0    Sam Worthington
# 1          Titanic (1997)     0.5      194    1.0  Leonardo DiCaprio
# 2   Jurassic World (2015)     0.5      124    1.0        Chris Pratt
# 3     The Avengers (2012)     0.5      143    1.0  Robert Downey Jr.
# 4  The Dark Knight (2008)     0.5      152    1.0     Christian Bale
#
#                                    studio  votes
# 0  Twentieth Century Fox Film Corporation      1
# 1  Twentieth Century Fox Film Corporation      1
# ...

# %%
df['country'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'country'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-6b2728405e8b> in <module>()
# ----> 1 df['country'].value_counts()
#
# ...

# %%
cc1 = df[df['votes']==1]['country'].value_counts()
cc2 = df[df['votes']==2]['country'].value_counts()
cc3 = df[df['votes']==3]['country'].value_counts()
df = pd.DataFrame([cc1, cc2, cc3])
df.index = ['CC1','CC2', 'CC3']
df.plot(kind='bar',stacked=True, figsize=(10,5))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'votes'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-a8ad6bfacc10> in <module>()
# ...

# %%
df.head()
# Out:
#           U     F     G     S     C     I     A    J    N    H    D    B    M  \
# CC1  1386.0  41.0  40.0  25.0  23.0  19.0  14.0  9.0  8.0  7.0  6.0  3.0  3.0
# CC2     NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# CC3     NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#        T
# CC1  1.0
# CC2  NaN
# CC3  NaN
